# %%
import numpy as np
import matplotlib.pyplot as plt


d = np.linspace(-2,2,3000)
x,y = np.meshgrid(d,d)
mask = (y>=-0.2) & (y<=0.2) &(x>=-0.2) & (x<=0.2) & (y>=x)
plt.imshow( ( mask).astype(int) , 
                extent=(x.min(),x.max(),y.min(),y.max()),origin="lower", cmap="Greys", alpha = 0.3);

x = np.linspace(-0.2, 0.2, 200)
# y >= 2
y1 = (x*1) + 0


plt.plot(x, y1)
plt.plot(0.15, -0.05, 'o')
plt.xlim(-0.2,0.2)
plt.ylim(-0.2,0.2)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.show()
